# %% [markdown]
# # Файлы, модули
#
# Структура занятия:
#
# 1) работа с файлами
#
# 2) модули и импорт
#
# 3) пакеты, библиотеки
#
# 4) пакетные менеджеры и и работа с зависимостями
#
# 5) виртуальное окружение

# %% [markdown]
# ## Работа с файлами
#
# Файлы используются программами для долговременного хранения информации, как необходимой для собственной работы (например, настройки), так и полученной во время ее исполнения
#
# Файлы хранятся в файловой системе - каталоге, определяющим способ организации, хранения и именования данных
#
# Для того, чтобы найти файл в файловой системе необходимо знать к нему **путь** - узлы дерева файловой системы, которые нужно пройти, чтобы до него добраться.
#
# Путь может быть:
#
#     - абсолютным (полным): указывает на одно и то же место в файловой системе вне зависимости от текущей рабочей директории;
#     - относительным: путь по отношению к текущему рабочему каталогу пользователя или активных приложений.
#
# В Python работа с файлами осуществляется через специальный абстрактный файловый объект. Стандартный способ создания файлового объекта - функция `open()`. `open()` поддерживает контекстный доступ при помощи оператора `with`.
#
# `open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)`
#
# - file - путь к файлу
# - mode - режим
#
# режим     |Значение
# --------- |---------------------------------------------------------------
# 'r'       |Открыть для чтения (по умолчанию)
# 'w'       |Открыть для записи (если файл существует, то очищается)
# 'x'       |Открыть для создания с эксклюзивными правами (ошибка, если файл существует)
# 'a'       |Открыть для добавления (если файл существует)
# 'b'       |Двоичный режим
# 't'       |Текстовый режим (по умолчанию)
# '+'       |Открыть для чтения и записи
#
# - encoding – наименование кодировки, используемой при чтении/записи файла (например, 'utf-8')
#
# Файловый объект поддерживает несколько методов:
# - `.name` - имя файла
# - `.mode` - режим доступа
# - `.closed` - возвращает, закрыт ли файл?
# - `.close(self, /)` - закрыть файл
# - `.read(self, size=-1, /)` - читает до size байт из файлового объекта, либо весь файл
# - `.readline(self, size=-1, /)` - читает следующую строку (до size байт)
# - `.write(self, text, /)` - записывает объект text
# - `.readlines(self, hint=-1, /)` - читает все строки до конца файла и возвращает их в виде списка
# - `.writelines(self, lines, /)` - записывает в файл последовательность объектов lines
# - ...

# %%
with open('saltan.txt', 'r') as fo:
    file_content = fo.read()  # весь файл был загружен в память

try:
    fo = open('saltan.txt', 'r')
    file_content = fo.read() 
finally:
    fo.close()

# %%
text = file_content.lower().replace('\n', ' ').split(' ')

text[:10]
# Out:
# ['три',
#  'девицы',
#  'под',
#  'окном',
#  'пряли',
#  'поздно',
#  'вечерком.',
#  '«кабы',
#  'я',
#  'была']

# %%
text = []

with open('saltan.txt', 'r') as fo:
    for line in fo:
        line_text = line.lower().replace('\n', ' ').split(' ')   # только 1 линия загружена в память
        text.extend(line_text)
        
text[:10]
# Out:
# ['три',
#  'девицы',
#  'под',
#  'окном',
#  '',
#  'пряли',
#  'поздно',
#  'вечерком.',
#  '',
#  '«кабы']

# %%
with open('saltan.txt') as fo:
    file_content = fo.read()
    
text = file_content.lower()[::-1].capitalize()

with open('saltan-reversed.txt', 'w') as fo:
    fo.write(text)

# %% [markdown]
# Для продвинутьй работы с файлами существуют модули `os`, `pathlib`, `glob`, `shutil`
#
# `os` - базовый модуль для работы с файловой системой
#
# `pathlib` - предлагает классы, представляющие пути к файловой системе с семантикой, подходящей для различных операционных систем.
#
# `glob` - модуль для поиска файлов в ФС
#
# `shutil` - модуль для копирования и архивирования файлов и деревьев каталогов

# %%
import os.path

os.path.abspath('saltan.txt')
# Out:
# '/Users/mpkaraulov/PycharmProjects/lections/8_modules/saltan.txt'

# %%
from pathlib import Path

copied = Path('new_saltan.txt')
copied.unlink(missing_ok=True)  # удалим файл, если он существует

# %%
from pathlib import Path
from shutil import copyfile

source = Path('saltan.txt')
destination = Path('new_saltan.txt')
copyfile(source, destination)
# Out:
# PosixPath('new_saltan.txt')

# %%
from glob import glob

top_level_txt_files = glob('*.txt')  # такой запрос поозволит найти файлы только в текущем каталоге
top_level_txt_files
# Out:
# ['new_saltan.txt', 'saltan.txt', 'saltan-reversed.txt']

# %%
from pathlib import Path  # pathlib является наиболее современным модулем для работы с ФС. Рекомендую ознакомиться

lections_level_py_files = Path.cwd().parent.rglob('*.py')
list(lections_level_py_files)
# Out:
# [PosixPath('/Users/mpkaraulov/PycharmProjects/lections/main.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/t.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/2_types/mem.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/2_types/.ipynb_checkpoints/mem-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/process_sample1.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/service.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/server.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/client.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/process_sample2.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/t.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/.ipynb_checkpoints/client-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/.ipynb_checkpoints/service-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/.ipynb_checkpoints/process_sample1-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/.ipynb_checkpoints/process_sample2-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/13_conc/.ipynb_checkpoints/server-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/redis_lock_perfect.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/redis_lock.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/app.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/.ipynb_checkpoints/redis_lock_perfect-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/.ipynb_checkpoints/redis_lock-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/model.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/storage/redis_.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/storage/protocol.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/storage/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/storage/mongo_.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/storage/postgres_.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/12_storages/account/storage/mock.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/6_oop/t.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/service.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/aiohttp_sample_1.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/flask_sample_1.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/aiohttp_service.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/hident.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/fastapi_sample_1.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/.ipynb_checkpoints/service-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/.ipynb_checkpoints/hident-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/14_web/.ipynb_checkpoints/aiohttp_service-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/test_pytest.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/circle.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/circle_doctest.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/dd.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/dd_saved.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/.ipynb_checkpoints/dd_saved-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/.ipynb_checkpoints/circle-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/9_testing/.ipynb_checkpoints/dd-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/8_modules/app.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/8_modules/consumer_producer/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/8_modules/consumer_producer/producer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/8_modules/consumer_producer/consumer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/8_modules/consumer_producer/utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/8_modules/consumer_producer/entities.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/8_modules/.ipynb_checkpoints/app-checkpoint.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/bin/activate_this.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/decorator.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jsonpointer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/ipykernel_launcher.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/_virtualenv.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/pandocfilters.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/six.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/rfc3339_validator.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/rfc3986_validator.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/py.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nest_asyncio.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/typing_extensions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/binary.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/raw_bson.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/decimal128.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/int64.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/objectid.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/dbref.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/code.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/tz_util.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/json_util.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/datetime_ms.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/max_key.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/errors.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/timestamp.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/son.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/min_key.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/codec_options.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/regex.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/bson/_helpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/draft06.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/draft07.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/indent.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/generator.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/ref_resolver.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/draft04.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/fastjsonschema/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/overrides/typing_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/overrides/final.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/overrides/enforce.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/overrides/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/overrides/overrides.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/overrides/signature.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/logging.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/signals.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/sessions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/config.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/templating.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/globals.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/blueprints.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/cli.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/wrappers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/app.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/debughelpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/scaffold.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/ctx.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/typing.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/testing.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/helpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/views.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/json/provider.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/json/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/flask/json/tag.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/async_timeout/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/appnope/_nope.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/appnope/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/appnope/_dummy.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/tags.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/_musllinux.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/metadata.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/_parser.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/requirements.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/_structures.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/markers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/_manylinux.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/_tokenizer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/specifiers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/packaging/_elffile.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_ws.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/worker.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/multipart.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_response.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/client_ws.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/test_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/tracing.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_middlewares.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/http_exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_app.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/streams.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_protocol.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/log.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/client.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_urldispatcher.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_request.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/http_websocket.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/client_proto.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/locks.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_runner.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_server.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/base_protocol.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/payload.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/client_reqrep.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/http.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_log.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/resolver.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/formdata.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/payload_streamer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_routedef.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/connector.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/client_exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/typedefs.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/hdrs.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/web_fileresponse.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/http_writer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/tcp_helpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/helpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/http_parser.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/cookiejar.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/pytest_plugin.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/aiohttp/abc.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/hstspreload/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_types.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_threadlock.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_backends/sync.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_backends/asyncio.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_backends/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_backends/trio.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_backends/base.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_backends/auto.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_async/http_proxy.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_async/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_async/http2.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_async/http11.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_async/connection.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_async/base.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_async/connection_pool.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_sync/http_proxy.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_sync/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_sync/http2.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_sync/http11.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_sync/connection.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_sync/base.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/wcwidth/wcwidth.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/wcwidth/table_zero.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/wcwidth/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/wcwidth/table_vs16.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/wcwidth/table_wide.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/wcwidth/unicode_versions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_logging.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_socket.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_url.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_http.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_wsdump.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_ssl_compat.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_handshake.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_app.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_abnf.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_core.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_cookiejar.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/test_cookiejar.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/test_websocket.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/test_abnf.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/test_http.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/echo-server.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/test_url.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/websocket/tests/test_app.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/markupsafe/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/markupsafe/_native.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/command.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/paths.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/application.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/troubleshoot.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/migrate.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/jupyter_core/utils/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/widgetsnbextension/_version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/widgetsnbextension/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_readers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_receivebuffer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_writers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_abnf.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_state.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_util.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_events.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_headers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/_connection.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_against_stdlib_http.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_connection.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_io.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_util.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_state.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_helpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_receivebuffer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_events.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/helpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h11/tests/test_headers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/enums.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/langhungarianmodel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/mbcssm.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/langthaimodel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/compat.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/langbulgarianmodel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/euckrprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/sjisprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/cp949prober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/euctwfreq.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/langhebrewmodel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/chardistribution.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/latin1prober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/charsetprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/gb2312prober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/mbcharsetprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/langcyrillicmodel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/euctwprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/codingstatemachine.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/escprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/universaldetector.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/utf8prober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/gb2312freq.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/mbcsgroupprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/langgreekmodel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/eucjpprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/jisfreq.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/escsm.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/langturkishmodel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/sbcharsetprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/big5freq.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/euckrfreq.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/big5prober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/hebrewprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/charsetgroupprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/sbcsgroupprober.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/jpcntx.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/cli/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/chardet/cli/chardetect.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/webencodings/labels.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/webencodings/mklabels.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/webencodings/x_user_defined.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/webencodings/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/webencodings/tests.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/pulldom.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/expatbuilder.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/xmlrpc.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/cElementTree.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/sax.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/lxml.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/common.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/minidom.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/expatreader.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/defusedxml/ElementTree.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/validator.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/_struct.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/notebooknode.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/_version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/warnings.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/json_compat.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/converter.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/current.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/_imports.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/reader.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/sign.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/sentinel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v1/convert.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v1/rwbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v1/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v1/nbbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v1/nbjson.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/corpus/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/corpus/words.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/corpus/tests/test_words.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/corpus/tests/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v2/convert.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v2/rwbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v2/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v2/nbbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v2/nbjson.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v2/nbpy.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v2/nbxml.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v4/convert.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v4/rwbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v4/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v4/nbbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v4/nbjson.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v3/convert.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v3/rwbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v3/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v3/nbbase.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v3/nbjson.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/nbformat/v3/nbpy.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/toc.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/list_parser.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/util.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/core.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/markdown.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/block_parser.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/helpers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/inline_parser.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/_base.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/toc.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/_rst.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/admonition.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/include.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/_fenced.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/directives/image.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/renderers/html.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/renderers/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/renderers/markdown.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/renderers/_list.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/renderers/rst.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/task_lists.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/abbr.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/spoiler.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/ruby.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/formatting.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/url.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/table.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/math.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/footnotes.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/speedup.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/mistune/plugins/def_list.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/config.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/events.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/frame_buffer.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/stream.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/connection.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/settings.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/errors.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/windows.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/h2/utilities.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/attrs/setters.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/attrs/validators.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/attrs/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/attrs/exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/attrs/converters.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/attrs/filters.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/hpack/compat.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/hpack/hpack.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/hpack/hpack_compat.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/hpack/huffman_table.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/hpack/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/hpack/huffman.py'),
# ...
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/argon2/low_level.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/argon2/_password_hasher.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/argon2/exceptions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/argon2/_legacy.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/argon2/profiles.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/argon2/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/argon2/_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/public_api.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_version.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/launcher/handlers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/launcher/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/launcher/winapi.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/launcher/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/launcher/debuggee.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/launcher/output.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/server/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/server/api.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/server/cli.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/server/attach_pid_injected.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/adapter/sessions.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/adapter/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/adapter/launchers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/adapter/servers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/adapter/clients.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/adapter/components.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/adapter/__main__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/log.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/util.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/singleton.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/sockets.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/timestamp.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/json.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/stacks.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/common/messaging.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/force_pydevd.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/_util.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/_pydevd_packaging.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/conftest.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/runfiles.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd_file_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd_tracing.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydev_app_engine_debug_startup.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydev_coverage.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pycompletionserver.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevconsole.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydev_run_in_console.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/setup.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/interpreterInfo.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/setup_pydevd_cython.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydev_pysrc.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/stubs/_django_manager_body.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles_unittest.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles_coverage.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles_nose.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles_pytest2.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles_parallel_client.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles_xml_rpc.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/pydev_runfiles_parallel.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_vars.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_command_line_handling.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_frame_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_breakpoints.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_plugin_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_process_net_command_json.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_timeout.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_reload.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_io.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command_factory_json.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command_factory_xml.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_xml.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_constants.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_trace_dispatch.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_extension_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_dont_trace_files.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_custom_frames.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_console.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_filtering.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevconsole_code.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_referrers.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_extension_api.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/__init__.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_stackless.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_collect_bytecode_info.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_bytecode_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_trace_api.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_trace_dispatch_regular.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_save_locals.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_additional_thread_info_regular.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_suspended_frames.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_thread_lifecycle.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_json_debug_options.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_safe_repr.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_traceproperty.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_import_class.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_runpy.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_cython_wrapper.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_additional_thread_info.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_api.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_dont_trace.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_utils.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_net_command.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_signature.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_vm_type.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_gevent_integration.py'),
#  PosixPath('/Users/mpkaraulov/PycharmProjects/lections/venv/lib/python3.11/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm_constants.py'),
#  ...]

# %% [markdown]
# ## Модули и пакеты
#
# Модуль - средство языка программирования, позволяющее объединить вместе данные и функции и использовать их как одну функционально-законченную единицу.
#
# Модуль - отдельный файл с кодом на Python, содержащий функции и данные. Любой файл с расширением `*.py` является модулем
#
# Пакеты являются еще более крупной единицей и представляют собой набор взаимосвязанных модулей, предназначенных для решения задач определенного класса
#
# Пакеты в Python - это способ структуризации модулей. Пакет представляет собой каталог, в котором содержатся модули и другие пакеты и обязательный файл `__init.py__`, отвечающий за инициализацию пакета.
#
# Все модули/пакеты в Python можно разделить на 4 категории:
# - Встроенные
# - Стандартная библиотека
# - Сторонние - установленные с помощью пакетного менеджера из каталога пакетов
# - Пользовательские или собственные - созданные разработчиков

# %% [markdown]
# ### Организация кода 1-го проекта (Архитектурные паттерны)
#
# Подходы, от простого и примитивного с сложному и прогрессивному:
# 1. Flat structure - хранение всего кода в корневой директории до тех пор, пока сохраняется понимание того, как это работает и где что находится
# ```
#   ./messenger-flat-structure
#      \_ .dockerignore
#      \_ .gitignore
#      \_ actions.toml
#      \_ alert.yaml
#      \_ api1_chat_get_messages_post_handler.py
#      \_ app.toml
#      \_ backoff_factory.py
#      \_ chat_model.py
#      \_ chat_service.py
#      \_ chat_storage.py
#      \_ codegen.toml
#      \_ Dockerfile
#      \_ __main__.py
#      \_ __init__.py
#      \_ message_model.py
#      \_ message_spec_contract.py
#      \_ message_storage.py
#      \_ mock_transaction.py
#      \_ postgresql.py
# ```

# %% [markdown]
# 2. Standard Project Layout - разделяем проект по зонам ответственности, по функционалу
# ```
# ./messenger-standart-layout
#     \_ api
#     \_ brief
#     \_ cmd
#     \_ lib
#        \_ api
#        \_ chat
#        \_ consumer
#        \_ database
#        \_ db
#        \_ errors
#        \_ generated
#        \_ message
#        \_ middleware
#        \_ retry
#        \_ transaction
#        \_ user
#        ...
#     \_ .dockerignore
#     \_ .gitignore
#     \_ actions.toml
#     \_ alert.yaml
#     \_ app.toml
#     \_ codegen.toml
#     \_ Dockerfile
#     \_ README.md
#     ...
# ```

# %% [markdown]
# 3. Layered architecture - добавляем группировку по доменной области
# ```
# ./messenger-l-a
#     \_ lib
#        \_ application
#           \_ chat
#              \_ service.py
#        \_ domain
#           \_ chat
#           \_ message
#           \_ user
#        \_ infrastructure
#           \_ database
#           \_ db
#           \_ errors
#           \_ generated
#           \_ middleware
#           \_ pg_repository
#           \_ retry
#           \_ transaction
#        \_ presentation
#           \_ chat
#              \_ api
#              \_ consumer
#        ...
#     ...
# ```

# %% [markdown]
# 4. Clean Architecture - все слои в данной архитектуры обслуживают бизнес слои, бизнес слой в свою очередь ничего не знает о обслуживающих слоях
#     - Domain - также как и в других архитектурах - это самый центральный слой в котором хранятся центральные правила нашей бизнес логики.
#     - Application - это слой с дополнительной бизнес логикой, которая может представлять собой основные бизнес сценарии(use cases)
#     - Presentation - содержит контроллеры, которые все оркестрируют в себе и отвечают за представление.
#     - Infrastructure - фреймворки, сборка зависимостей, провайдеры, адаптеры.
#
# ```
# ./messenger-c-a
#     \_ lib
#        \_ generated
#        \_ domain
#           \_ chat
#           \_ message
#           \_ user
#        \_ infrastructure
#           \_ db
#           \_ middleware
#           \_ pg_repository
#           \_ retry
#           \_ transaction
#           \_ qaas
#        \_ rpc
#           \_ handler
#              \_ getmessages
#              \_ sendmessages
#        \_ usecase
#        ...
#     ...
# ```

# %% [markdown]
# ## Подключение модулей
#
# Ключевое слово - `import`.
#
# Все импорты должны располагаться в начале файла
#
# ```python
# import module  # импортруем модуль
#
# import module as mod  # импортруем модуль и даём ему псевдоним, далее необходимо будет использовать имя псевдонима
#
# from module import object as obj  # импортруем из модуля объект, даём ему псевдоним
#
# from module import object1, object2, ...  # импортруем из модуля несколько объектов
#
# from module import *  # импортруем из модуля все объекты. Такой способ не рекомендуется
#
# import package  # импортруем весь пакет
#
# import package.module  # импортруем модуль из пакета
#
# cls_obj = module.Class()
# cls_obj_prepared = mod.fun(cls_obj, obj)
# result = package.module.fun(cls_obj_prepared, package.CONST)
# ```
#
# Собственные модули должны называться в snake_case стиле, не следует называть модули и пакеты аналогично встроенным
#
# Каждый  модуль имеет атрибуты:
# - `__name__` - Полное имя модуля
# - `__doc__` - Строка документации
# - `__file__` - Полный путь к файлу

# %%
import math

math.__name__, math.__file__
# Out:
# ('math',
#  '/Users/mpkaraulov/.pyenv/versions/3.11.3/lib/python3.11/lib-dynload/math.cpython-311-darwin.so')

# %% [markdown]
# При разработке собственного модуля следует определить, будет ли он служить только для импорта, или будет запускаться самостоятельно. В первом случае, будем говорить о модуле как о библиотеке, такой модуль не должен иметь точки входа. Во втором случае будем говорить о модуле как об исполняемом (скрипт или программа), такой модуль должен иметь точку входа:
#
# ```python
# if __name__ == "__main__":
#     ...
# ```

# %% [markdown]
# ## Пакетные менеджеры и и работа с зависимостями
#
# ### pip
#
# pip — система управления пакетами, которая используется для установки и управления программными пакетами, написанными на Python
#
# Установка самой последней версии пакета:
#
# `pip install package-name`
#
# `python -m pip <аргументы>`
#
# Установка конкретной версии пакета:
#
# `pip install package-name==1.0.0`
#
# pip предоставляет возможность управлять всеми пакетами и их версиями с помощью файла `requirements.txt`. Это позволяет эффективно воспроизводить весь необходимый список пакетов в отдельном окружении
#
# `pip install -r requirements.txt`
#
# Удаление пакета:
#
# `pip uninstall package-name`
#
# Получение списка установленных пакетов:
#
# `pip list`
#
# Файл внешних зависимостей `requirements.txt` - текстовый файл, где на каждой строке перечислено ровно по одной зависимости. Не является стандартом, название является соглашением и не более. Зависимости могут быть разделены по нескольким файлам в зависимости от желаемого для установки окружения. Так, кроме основного файла зависимостей могут также быть `dev-requirements.txt` и `test-requirements.txt`. `test-requirements.txt` будет содержать пакеты нужные для тестирования приложения, а `dev-requirements.txt` может содержать пакеты для статического анализа кода (`mypy`).
# Пример файла зависимостей:
# ```
# docker==3.7.2
# glom~=19.2.0
# graphite-client>=1.1.1
# click==7.1.2
# pymongo
# python-dateutil==2.8.1
# ```
#
# Pip и requirements.txt имеют один очень существенный недостаток: для того чтобы хоть сколько-нибудь обеспечить воспроизводимость окружения, необходимо жёстко фиксировать версии пакетов. Для того что гарантировать воспроизводимость - необходимо вручную фиксировать и сверять контрольные суммы пакетов. Почему так получается:
# - новые версии пакетов могут существенно отличаться от старых
# - в зависимостях пакетов могут быть конфликты
# - в приватных индексах (не pypi) версии пакетов могут перезаписываться, а следовательно будут отличаться только их контрольные суммы
#
# ### poetry
#
# Poetry - это инструмент для управления зависимостями в Python проектах
#
# Poetry создает изолированное виртуальное окружение для проекта, устанавливая все необходимые пакеты и разрешая конфликты зависимостей (если они в принципе решаемы).
#
# Для инициализации poetry необходимо в корневом каталоге проекта выполнить:
#
# `poetry init`
#
# В файле `pyproject.toml` будет содержаться описание Poetry-проекта: название, описание, используемый репозиторий, зависимости проекта и т.д. С его помощью можно легко организовать зависимости проекта (pyproject.toml по сути преемник requirements.txt)
# Пример файла зависимостей:
# ```
# [tool.poetry]  # метаданные проекта
# name = "project-name"
# version = "1.0.0"
# description = "-"
# authors = ["<mpkaraulov@avito.ru>"]
#
# [tool.poetry.dependencies]  # зависимости, необходимые для проекта
# python = ">=3.8,<3.10"
# paas-zero = "^0.8.0"
# glom = "^20.11.0"
# lxml = "^4.9.1"
#
# [tool.poetry.dev-dependencies]  # зависимости разработки
# pytest = "^6.2.5"
#
# [build-system]  # данные самого poetry
# requires = ["poetry-core>=1.0.0"]
# build-backend = "poetry.core.masonry.api"
#
# [[tool.poetry.source]]  # опционально - дополнительные индексы и т.п.
# name = "avito-pypi"
# url = "https://pypi.k.avito.ru/pypi/"
# default = true
# ```
#
# Установка пакета:
#
# `poetry add package-name`
#
# Удаление:
#
# `poetry remove package-nam`
#
# Установка всех пакетов из `pyproject.toml`. При первой установке создается файл `.lock`, который содержит фактические номера версий каждого установленного пакета. Номера версий в .lock файле имеют более высокий приоритет, чем находящиеся в pyproject.toml
#
# `poetry install`
#
# Обновление всех пакетов из `pyproject.toml`. Если для пакетов в pyproject.toml существуют более новые версии, они будут установлены, и .lock файл будет обновлён
#
# `poetry install`

# %% [markdown]
# ## Виртуальное окружение
#
# [Ссылка](../1/lec.ipynb#Виртуальное-окружение-Python)
#
# Установка из PyCharm
